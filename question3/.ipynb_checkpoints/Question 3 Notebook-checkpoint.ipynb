# %%
# %matplotlib inline

from plot_questions import *
from convolve_image import * # requires Pillow

# %% [markdown]
# ### a) Implementing Bessel function of the first kind of order, x=4

# %%
bessel(1,4) # implemented routine result
# Out:
# -0.06604332802354913

# %%
jv(1,4)
# Out:
# -0.066043328023549244

# %%
plot_bessel()

# %% [markdown]
# ### b) Plotting point spread function

# %%
plot_point_spread()

# %%
show_point_spread_img()

# %% [markdown]
# ### c) Image convolution

# %%
convolve_img("proxima_centauri.jpg")

# %% [markdown]
# **If you get an error:**
# Make sure Pillow is installed in your environment.
