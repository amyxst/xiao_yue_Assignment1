# %%
# %matplotlib inline

from plot_questions import *
from convolve_image import *

# %% [markdown]
# ### a) Implementing Bessel function of the first kind of order, x=4

# %%
bessel(1,4) # implemented routine result

# %%
jv(1,4)
# Out:
# -0.066043328023549244

# %%
plot_bessel()

# %% [markdown]
# ### b) Plotting point spread function

# %%
plot_point_spread()

# %%
show_point_spread_img()

# %% [markdown]
# ### c) Image convolution

# %%
convolve_img("proxima_centauri.jpg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-ab3b3582b3f5> in <module>()
# ----> 1 convolve_img("proxima_centauri.jpg")
#
# /cita/d/homes/home-2/course17/Documents/xiao_amy_Assignment1/question3/convolve_image.py in convolve_img(fname)
#       7
#       8 def convolve_img(fname):
# ----> 9     img = misc.imread(fname)
#      10     #print img
#      11     print img.shape
#
# AttributeError: 'module' object has no attribute 'imread'

# %% [markdown]
# **ERROR NOTE:**
# Run `python convolve_image.py` in terminal to see convolution output.
#
# Jupyter Notebook is unable to import `imread` due to PIL being missing for some reason, but the import works fine in terminal.
